# %% [markdown]
# <a href="https://colab.research.google.com/github/THEVS11/project_vyansh/blob/main/CODEV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def gen():
     print("Please enter the following General Information")
     first_name = input("First Name: ")
     middle_name = input("Middle Name: ")
     last_name = input("Last Name: ")
     aadhar_no = input("Aadhar Number: ")
     aadhar_name = input("Name (as in aadhar card): ")
     pan_no = input("PAN Number: ")
     pan_name = input("Name (as in PAN card): ")
     return first_name, middle_name, last_name, aadhar_no, aadhar_name, pan_no, pan_name
def pers():
    print("Please enter your the following Personal Information")
    contact_no = input("Contact Number: ")
    email_id = input("Email ID: ")
    dob_str = input("Date of Birth (yyyy/mm/dd): ")
    dob = datetime.datetime.strptime(dob_str, "%Y/%m/%d")
    father_name = input("Father's Name: ")
    nationality = input("Nationality: ")
    blood_group = input("Blood Group: ")
    return contact_no, email_id, dob, father_name, nationality, blood_group
def adr():
    print("Please enter your following Address Details")
    house_no = input("House/Flat Number: ")
    locality = input("Street / Locality: ")
    town = input("Town: ")
    district = input("District: ")
    state = input("State: ")
    pincode = input("Pincode: ")
    post_office = input("Post Office: ")
    return house_no, locality, town, district, state, pincode, post_office
def edu():
    print("Please enter your following Education Details")
    high_school_name = input("High School Name: ")
    high_school_board = input("High School Board: ")
    inter_school_name = input("Senior Secondary School Name: ")
    inter_school_board = input("Senior Secondary School Board: ")
    degree = input("Latest Degree: ")
    return high_school_name, high_school_board, inter_school_name, inter_school_board, degree
import datetime

print("Welcome to the Citizen Information System!")

general_info = pers_info = address_info = edu_info = None
while True:
    choice = int(input('''Kindly choose from the following options by entering the number next to them:
                    1 : General Information
                    2 : Personal Information
                    3 : Address Details
                    4 : Education Details '''))
    if choice == 1:
        general_info = gen()
        n=input("do you want to add mmore information: Y/N ")
        if n== 'Y':
            continue
        elif n== 'N':
            break
        else:
            print("INVALID INPUT")
    elif choice == 2:
        pers_info = pers()
        n=input("do you want to add mmore information: Y/N ")
        if n== 'Y':
            continue
        elif n== 'N':
            break
        else:
            print("INVALID INPUT")
    elif choice == 3:
        address_info = adr()
        n=input("do you want to add mmore information: Y/N ")
        if n== 'Y':
            continue
        elif n== 'N':
            break
        else:
            print("INVALID INPUT")
    elif choice == 4:
        edu_info = edu()
        n=input("do you want to add mmore information: Y/N ")
        if n== 'Y':
            continue
        elif n== 'N':
            break
        else:
            print("INVALID INPUT")
    else:
        print("Error: Invalid Choice. Please Try Again")
display = int(input("Enter the above numbers to display the corresponding details: "))
if display == 1:
    print("General Information:")
    print(general_info)
elif display == 2:
    print("Personal Information:")
    print(pers_info)
elif display == 3:
    print("Address Details:")
    print(address_info)
elif display == 4:
    print("Education Details:")
    print(edu_info)
else:
    print("Error: Invalid Choice.")
# Out:
# Welcome to the Citizen Information System!
# Kindly choose from the following options by entering the number next to them:
#                     1 : General Information
#                     2 : Personal Information
#                     3 : Address Details
#                     4 : Education Details 1
# Please enter the following General Information
# First Name: Vyansh
# Middle Name:
# Last Name: Sinha
# Aadhar Number: 123456789
# Name (as in aadhar card): VS
# PAN Number: 12334545
# Name (as in PAN card): VS
# do you want to add mmore information: Y/N N
# Enter the above numbers to display the corresponding details: 1
# General Information:
# ('Vyansh', '', 'Sinha', '123456789', 'VS', '12334545', 'VS')
